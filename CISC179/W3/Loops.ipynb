# %% [markdown]
# <a href="https://colab.research.google.com/github/yshybasdccd/assignments/blob/main/CISC179/W3/Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loops in Python
#
# A sequence of instructions that repeats until a certain condition is met
#
# ## Objective
# Understand how loops are applied
#
# ## Prerequisite
#
# - Decision statements
# - Input functions
# - Python literals
# - Programming variables
#
# ## What do you need to complete this exercise?
#
# You can perform this exercise in any Python IDE, including JupyterLab or Google Colab.

# %% [markdown]
# ### While loop
#
# a. Please write Python code using a while loop to perform the following steps.
#
# 1. Take any non-negative and non-zero integer number and name it ```n0```
# 2. if the number is even, evaluate a new ```n0``` as ```n0 ÷ 2```;
# 3. Otherwise, if the number is odd, evaluate a new ```n0``` as ```3 * n0 + 1```;
# 4. if ```n0``` is not equal to 1, go to point 2.
#
# #### Sample input: ```16```
#
# #### Expected output: ###
#
# ```
# 8
# 4
# 2
# 1
# steps = 4
# ```

# %%
# Write your code here.
steps = 0
n0 = 0
while(n0 <= 0):
  n0 = int(input("Enter a positive integer: "))
  if(n0 <= 0):
    print("Invalid input. Please enter a positive integer.")
while(n0>1):
  if( n0 % 2 == 0):
    n0 = n0 / 2
  else:
    n0 = 3 * n0 + 1
  print(int(n0))
  steps = steps + 1
print("steps = ", steps)
# Out:
# Enter a positive integer: 16
# 8
# 4
# 2
# 1
# steps =  4

# %% [markdown]
# b. Write code that uses a while loop and runs indefinitely. Modify the same code to resolve the infinite loop issue.

# %%
# Write your code here.

# while(True):
#   print("Hello")

i=0
# while(i>=0):
#   print("Hello")
#   i = i + 1

while(i<10):
  print("Hello")
  i = i + 1
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello

# %% [markdown]
# c. Write a program that takes two integers as input and asks the user to choose an arithmetic operation to perform with those numbers. At the end of the program, prompt the user with the question, "Do you want to continue?" If the user selects "Y" or "y," the program should restart; otherwise, it should exit and display the message, "Have a good day."

# %%
# Write your code here.
continueProgram = "Y"
while(continueProgram == "Y" or continueProgram == "y"):
  print("Enter two integers: ")
  a = int(input())
  b = int(input())
  while True:
    print("Choose an arithmetic operation to perform with those numbers(+, -, *, /): ")
    choice = input()
    if(choice == '+'):
      print("a + b = ", a + b)
      break
    elif(choice == '-'):
      print("a - b = ", a - b)
      break
    elif(choice == '*'):
      print("a * b = ", a * b)
      break
    elif(choice == '/'):
      if(b != 0):
        print("a / b = ", a / b)
        break
      else:
        print("Invalid input. Cannot divide by 0.")
    else:
      print("Invalid choice")
  print("Do you want to continue? (Y/N)")
  continueProgram = input()
print("Have a good day.")
# Out:
# Enter two integers:
# 5
# 0
# Choose an arithmetic operation to perform with those numbers(+, -, *, /):
# /
# Invalid input. Cannot divide by 0.
# Choose an arithmetic operation to perform with those numbers(+, -, *, /):
# *
# a * b =  0
# Do you want to continue? (Y/N)
# y
# Enter two integers:
# 4
# 4
# Choose an arithmetic operation to perform with those numbers(+, -, *, /):
# 4
# Invalid choice
# Choose an arithmetic operation to perform with those numbers(+, -, *, /):
# 4
# Invalid choice
# Choose an arithmetic operation to perform with those numbers(+, -, *, /):
# 132
# Invalid choice
# Choose an arithmetic operation to perform with those numbers(+, -, *, /):
# add
# Invalid choice
# Choose an arithmetic operation to perform with those numbers(+, -, *, /):
# +
# a + b =  8
# Do you want to continue? (Y/N)
# N
# Have a good day.

# %% [markdown]
# ### 2. For loops
#
# a. Write a code that counts the total number of characters in a text and also counts each character individually. For example, consider the sentence "To be, or not to be, that is the question." The code should determine the total number of letters and how many times each letter appears, including specific counts for the letters 't' and 'o', etc. Ignore the upper and lower cases letters, and any punctuations symbols. Use only for loop, while loop, break and continue statements where necessary.
#
# #### Sample input: ```To be, or not to be, that is the question```
#
# #### Expected output: ###
#
# ```
# Total number of alphabets: 30
# Total number of distinct alphabets are:
# T = 7
# o = 4
# ```
# > **Note:** The expected output above is incomplete.

# %%
# Write your code here.
sentence = input("Enter a sentence: ").lower().replace(",", "").replace(".", "")
totalAlphabets = 0
alphabetCount = {}
for char in sentence:
  if(char.isalpha()):
    totalAlphabets = totalAlphabets + 1
    if(char in alphabetCount):
      alphabetCount[char] = alphabetCount[char] + 1
    else:
      alphabetCount[char] = 1
print("Total number of alphabets: ", totalAlphabets)
print("Total number of distinct alphabets are:")
alphabetCount = dict(sorted(alphabetCount.items(), key=lambda item : item[1],reverse=True))
for char in alphabetCount:
  print(char, " = ", alphabetCount[char])
# Out:
# Enter a sentence: To be, or not to be, that is the question
# Total number of alphabets:  30
# Total number of distinct alphabets are:
# t  =  7
# o  =  5
# e  =  4
# b  =  2
# n  =  2
# h  =  2
# i  =  2
# s  =  2
# r  =  1
# a  =  1
# q  =  1
# u  =  1

# %% [markdown]
# ## Challenges
#
# Please describe the challenges you faced during the exercise.
# There were a few challenges on how to use dictionaries in Python and what are the methods for them to sort them in descending order.

# %% [markdown]
# Write your challenges here
