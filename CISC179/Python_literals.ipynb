# %% [markdown]
# <a href="https://colab.research.google.com/github/yshybasdccd/assignments/blob/main/CISC179/W2/Python_literals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python literals
#
# ## Objective
# 1. Understand how Python uses literals.
# 2. Differentiate Integer, Float, Boolean and String data types.
# 3. Understanding how arithmetic operations are performed and recognizing the precedence of operators.
#
# ## Prerequisite
#
# - Python & literals lecture
#
# ## What do you need to complete this exercise?
#
# You can perform this exercise in any Python IDE, including JupyterLab or Google Colab.

# %% [markdown]
# ### Literals
#
# a) What will the output be without using Python? Aim for 80% accuracy.
#
# ```print(5 + 2 - 2)``` = 5
#
# ```print(5 / 2)``` = 2.5
#
# ```print(6 // 2) # // integer division``` = 3
#
# ```print(2. * 3)``` = 6.0
#
# ```print(2 < 4)``` = True
#
# ```print(2 >= 2)``` = True
#
# ```print("Hello"+"World")``` = HelloWorld
#
# ```print("bla" * 3)``` = blablabla
#
# ```print(2 * 3 ** 3)``` = 54
#
# ```print(5 * 25 // 13 + 100 / 2 % 13 // 2)``` = 14
#
# ```print(2 * 3 % 5)``` = 1
#
# ```print((2 % -4), (2 % 4), (2 ** 3 ** 2))``` = -2, 2, 512

# %% [markdown]
# b) Please verify using Python to determine if you have achieved at least 80% correct answers.

# %%
# Write your code here
questions = [5+2-2, 5/2, 6//2, 2.*3, 2<4, 2>=2, "Hello"+"World", "bla"*3, 2*3**3, 5 * 25 // 13 + 100 / 2 % 13 // 2, 2 * 3 % 5,(2 % -4), (2 % 4), (2 ** 3 ** 2)]
answers = [5,2.5,3,6.0,True,True,"HelloWorld", "blablabla", 54,14,1,-2,2,512]
correctAnswers = 0
totalQuestions = 0

for q in questions:
  if q == answers.pop(0):
    correctAnswers=+1
  totalQuestions=+1

print(correctAnswers/totalQuestions*100, "% correct answers")

print("----------------")

print(5 + 2 - 2)

print(5 / 2)

print(6 // 2)

print(2. * 3)

print(2 < 4)

print(2 >= 2)

print("Hello"+"World")

print("bla" * 3)

print(2 * 3 ** 3)

print(5 * 25 // 13 + 100 / 2 % 13 // 2)

print(2 * 3 % 5)

print((2 % -4), (2 % 4), (2 ** 3 ** 2))
# Out:
# 100.0 % correct answers
# ----------------
# 5
# 2.5
# 3
# 6.0
# True
# True
# HelloWorld
# blablabla
# 54
# 14.0
# 1
# -2 2 512

# %% [markdown]
# ### Data type

# %% [markdown]
# a) What will the output be without using Python? Aim for 80% accuracy.
#
# ```type("Hello")``` = class str
#
# ```type(1+"2")``` = error
#
# ```type(1.)``` = class float
#
# ```type('A')``` = class str
#
# ```type(500)``` = class int
#
# ```type(True)``` = class bool
#
# ```type("False")``` = class str

# %% [markdown]
# Answer here

# %% [markdown]
# b) Please verify using Python to determine if you have achieved at least 80% correct answers.

# %%
# Write your code here
questions = ["Hello", 1., 'A',500,True,"False"]
answers = [str,float,str,int,bool,str]
correctAnswers = 0;
totalQuestions = 0

for q in questions:
  if type(q) == answers.pop(0):
    correctAnswers=+1
  totalQuestions=+1

print(correctAnswers/totalQuestions*100, "% correct")

# i did not include 1+"2", because it throws error and the program stops executing
# Out:
# 100.0 % correct

# %% [markdown]
# ### Operator precedence

# %% [markdown]
# a) Write your arithmetic expression that uses at least one operator from each group. For example ```5 * 25 % 13 + 100 / -2 * 13 // 2 ** 3```

# %%
# Write your code here
(5*3//4+(17-2)/3+1**5)%5
# Out:
# 4.0

# %% [markdown]
# b) What will the output be without using Python after writing your arithmetic expression? Use the table below for your reference.

# %% [markdown]
# | Priority | Operator                                                     | Notes                    |
# | :------- | :----------------------------------------------------------- | :----------------------- |
# | 1        | `**`                                                         | Right to left evaluation |
# | 2        | `+`, `-` (note: unary operators located next to the right of the power operator bind more strongly) | unary                    |
# | 3        | `*`, `/`, `//`, `%`                                          | Left to right evaluation |
# | 4        | `+`, `-`                                                     | binary                   |

# %% [markdown]
# Answer here
#
# (5*3//4+(17-2)/3+1**5)%5 = (3+5+1)%5 = 9%5 = 4.0

# %% [markdown]
# c) Please verify using Python to determine if you have done it correctly.

# %%
# Write your code here
print((5*3//4+(17-2)/3+1**5)%5)

# %% [markdown]
# ## Challenges
#
# Please describe the challenges you faced during the exercise.
#
# In this exercise I have decided to do some extra work and created a simple functionality that count % of correct answers for me.

# %% [markdown]
# Write your challenges here
