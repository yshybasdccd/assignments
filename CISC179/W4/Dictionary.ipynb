# %% [markdown]
# <a href="https://colab.research.google.com/github/yshybasdccd/assignments/blob/main/CISC179/W4/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dictionary in Python
# In Python, a dictionary is a built-in data structure that stores data in key-value pairs. It is an unordered, mutable (changeable) collection, where each key must be unique and immutable (e.g., string, number, or tuple), while the value can be of any data type.
#
# ## Objective
# - Understand how to create dictionary in Python
# - Apply various methods on a dictionary
# - Troubleshoot dictionary
#
# ## Prerequisite
#
# - Lists & tuples
# - Decision and loops
# - Input functions
#
#
# ## What do you need to complete this exercise?
#
# You can perform this exercise in any Python IDE, including JupyterLab or Google Colab.

# %% [markdown]
# # 1. Creating and accessing dictionary
#
# 1a) Create dictionary of your choice of keys and values. Create dictionary size of 10 elements.

# %%
# Write your code here.
my_info = {"name":"Yurii", 'surname':'Shyba', 'age':22, 'job':'software engineer', 'student':True, 'college':"Miramar College", 'location':'San Diego'}
my_info['course'] = 'CISC179'
my_info['prog_languages'] = 'JavaScript, Python'
my_info['favorite_game'] = 'CS2'

my_info
# Out:
# {'name': 'Yurii',
#  'surname': 'Shyba',
#  'age': 22,
#  'job': 'software engineer',
#  'student': True,
#  'college': 'Miramar College',
#  'location': 'San Diego',
#  'course': 'CISC179',
#  'prog_languages': 'JavaScript, Python',
#  'favorite_game': 'CS2'}

# %% [markdown]
# 1b. Take inputs from a user and add them in a dictionary called ```my_user_dict```
#
# Here is the example of an user input:
#
# SSN: 111-222-3333
#
# Name: Steve Hawkins
#
# The code continue to take user input and provide an option at the end of the user input; "Do you want to continue (Y/N)"
#
# Identify how many keys you need to create a dictionary.
#
# __Restrictions: Do not use functions and/or exceptions in this exercise__

# %%
# Write your code here.
my_user_dict = {}
while True:
  userKey = input("Please provide the name of the key: ")
  my_user_dict[userKey] = input('Please provide the value:')
  if input("Do you want to continue?(Y/N)").capitalize() == 'N':
    break

my_user_dict
# Out:
# Please provide the name of the key: SSN
# Please provide the value:111-222-3333
# Do you want to continue?(Y/N)y
# Please provide the name of the key: Name
# Please provide the value:Steve Hawkins
# Do you want to continue?(Y/N)n
# {'SSN': '111-222-3333', 'Name': 'Steve Hawkins'}

# %%
# List of tuples where each tuple represents a key-value pair

a = [("a", 1), ("b", 2), ("c", 3)]

# Convert the list of tuples into a dictionary

res = dict(a)

print(res)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# 1c. Based on the given tuple, create a code which checks for valid key & value pairs, and check for key duplication.
#
# The code should provide assistance to a user to correct the error. For key duplication, ask user to change the key
#
# __Restrictions: Do not use functions and/or exceptions in this exercise__

# %%
my_list = [("Name", "Sarah Connor"), ("Date of birth", "1 Jan 1980"), ("Address","1000 Black Mountain Drive",92126),("Name", "Jim Hawkins")]
my_list
# Out:
# [('Name', 'Sarah Connor'),
#  ('Date of birth', '1 Jan 1980'),
#  ('Address', '1000 Black Mountain Drive', 92126),
#  ('Name', 'Jim Hawkins')]

# %%
# Write your code here.
keysCreated = []
for item in my_list:
  if item[0].count(' ') > 0:
    print('The name of the key contains spaces, please remove them.', item)
    continue
  if keysCreated.count(item[0]) == 0:
    keysCreated.append(item[0])
  else:
    print("The key already exists, please change the key name.", item)

keysCreated
# Out:
# The name of the key contains spaces, please remove them. ('Date of birth', '1 Jan 1980')
# The key already exists, please change the key name. ('Name', 'Jim Hawkins')
# ['Name', 'Address']

# %% [markdown]
# 1d. Convert the following list into a dictionary. Automate the process by using the loop.
#
# __Restrictions: Do not use functions and/or exceptions in this exercise__

# %%
my_list = [10012,"Mango",43221,"Gala apple",14321,"Banana",10011,"Watermelon",123]
my_dictionary = {}
for i in range(len(my_list)):
  if i % 2 == 1:
    continue
  if i % 2 == 0 and i < len(my_list)-1:
    my_dictionary[my_list[i]] = my_list[i+1]

my_dictionary
# Out:
# {10012: 'Mango', 43221: 'Gala apple', 14321: 'Banana', 10011: 'Watermelon'}

# %% [markdown]
# 1e. Use the following text and count the number of words using dictionary. Remember The or the counts as 2.
#
# **The tiger (Panthera tigris) is a large cat and a member of the genus Panthera native to Asia. It has a powerful, muscular body with a large head and paws, a long tail and orange fur with black, mostly vertical stripes. It is traditionally classified into nine recent subspecies, though some recognise only two subspecies, mainland Asian tigers and the island tigers of the Sunda Islands.**

# %%
text = 'The tiger (Panthera tigris) is a large cat and a member of the genus Panthera native to Asia. It has a powerful, muscular body with a large head and paws, a long tail and orange fur with black, mostly vertical stripes. It is traditionally classified into nine recent subspecies, though some recognise only two subspecies, mainland Asian tigers and the island tigers of the Sunda Islands.'
restrictedCharacters = [',','.','(',')']
for item in restrictedCharacters:
  text = text.replace(item, '')
wordsList = text.split(' ')
wordsDictionary = {}
for item in wordsList:
  if item == "the" or item == "The":
    if(item in wordsDictionary):
      wordsDictionary[item] = wordsDictionary[item] + 2
    else:
      wordsDictionary[item] = 2
  else:
    if(item in wordsDictionary):
      wordsDictionary[item] = wordsDictionary[item] + 1
    else:
      wordsDictionary[item] = 1

wordCount = 0

for item in wordsDictionary.values():
  wordCount += item

wordCount
# Out:
# 70

# %% [markdown]
# # 2. Troubleshooting

# %%
d_orig = {123:"Coconut"}
d_copy = d_orig
print(d_orig)
print(d_copy)
# Out:
# {123: 'Coconut'}
# {123: 'Coconut'}

# %% [markdown]
# 2a. Change the content of ```d_copy``` and make sure the content does not affect the ```d_orig``` dictionary. Verify using the code.

# %%
# Write your code here
d_copy[123] = 'Apple'
print(d_orig)
print(d_copy)
# Out:
# {123: 'Apple'}
# {123: 'Apple'}

# %% [markdown]
# 2b. If it changes the content of the original dictionary, then propose how can you solve this problem.

# %%
# Write your code here
import copy
d_copy = copy.deepcopy(d_orig)
d_copy[123] = 'Apple'
print(d_orig)
print(d_copy)
# Out:
# {123: 'Coconut'}
# {123: 'Apple'}

# %% [markdown]
# 2c. Write a code that generates the following error and explain why there is such an error.
# ```
# TypeError: unhashable type: 'list'
# ```

# %%
# Write your code here
hash([1,2])
# This error happens, because it is possible to hash only immutable objects.
# The values of the list objects could be changed, resulting in a change of the object
# so that is why it is impossible to hash this object
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-9f6541d3b2ed> in <cell line: 0>()
#       1 # Write your code here
# ----> 2 hash([1,2])
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ## Challenges
#
# Please describe the challenges you faced during the exercise.

# %% [markdown]
# Write your challenges here
