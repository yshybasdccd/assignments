# %% [markdown]
# <a href="https://colab.research.google.com/github/yshybasdccd/assignments/blob/main/CISC179/W2/Input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # User input in Python
#
# ## Objective
# 1. Understand how ```input()``` function is applied.
#
# ## Prerequisite
#
# - Python literals lecture & lab
# - Programming variables lecture
#
# ## What do you need to complete this exercise?
#
# You can perform this exercise in any Python IDE, including JupyterLab or Google Colab.

# %% [markdown]
# ### User input
#
# a. Write a program that prompts the user to enter the weight of a person in kilograms and outputs the equivalent weight in pounds. (Note that 1 kilogram = 2.2 pounds).

# %%
# Write your code here
kg = float(input("Please, enter the weight of a person in kilograms: "))
lb = kg*2.2
print("The weight in kilogram is: ", kg, "\nThe weight in pounds is: ", lb)
# Out:
# Please, enter the weight of a person in kilograms: 100
# The weight in kilogram is:  100.0
# The weight in pounds is:  220.00000000000003

# %% [markdown]
# b. Interest on a credit card's unpaid balance is calculated using the average daily balance. Suppose that $netBalance$ is the balance shown in the bill, $payment$ is the payment made, $d1$ is the number of days in the billing cycle, and $d2$ is the number of days payment is made before biling cycle. Then, the average daily balance is: $$averageDailybalance = (netBalance \times d1 - payment \times d2)/d1$$.
#
# If the interest rate per month is, say, 0.0152, then the interest on the unpaid balance is: $interest = averageDailyBalance \times 0.0152$
#
# Write a program that accepts as input $netBalance$, $payment$, $d1$, $d2$, and $interest rate per month$. The program outputs the interest.

# %%
# Write your code here
netBal = float(input("Please enter the balance shown in the bill: "))
payment = float(input("Please enter the payment: "))
d1 = int(input("Please enter the number of days in the billing cycle: "))
d2 = int(input("Please enter the number of days payment is made before billing cycle: "))
interestratepermonth = float(input("Please enter the interest rate per month: "))
averageDailyBalance = (netBal * d1 - payment * d2)/d1
interest = averageDailyBalance * interestratepermonth
print("Interest is: ", interest)
# Out:
# Please enter the balance shown in the bill: 1000
# Please enter the payment: 250.5
# Please enter the number of days in the billing cycle: 28
# Please enter the number of days payment is made before billing cycle: 15
# Please enter the interest rate per month: 0.0152
# Interest is:  13.160214285714286

# %% [markdown]
# c. Two cars A and B leave an intersection at the same time. Car A travels west at an average speed of x miles per hour and car B travels south at an average speed of y miles per hour. Write a program that prompts the user to enter the average speed of both the cars and the elapsed time (in hours and minutes) and outputs the (shortest) distance between the cars.

# %%
# Write your code here
carASpeed = int(input("Enter Car A Speed in miles per hour: "))
carBSpeed = int(input("Enter Car B Speed in miles per hour: "))
hoursElapsed = int(input("Enter amount of hours elapsed: "))
minutesElapsed = int(input("Enter amount of minutes elapsed: "))
carADistance = carASpeed * (hoursElapsed+minutesElapsed/60)
carBDistance = carBSpeed * (hoursElapsed+minutesElapsed/60)
distance = (carADistance**2 + carBDistance**2)**0.5
print("The shortest distance between the cars is ", distance, "miles")
# Out:
# Enter Car A Speed in miles per hour: 65
# Enter Car B Speed in miles per hour: 40
# Enter amount of hours elapsed: 2
# Enter amount of minutes elapsed: 37
# The shortest distance between the cars is  199.70841591903155 miles

# %% [markdown]
# ### Troubleshooting
#
# Please troubleshoot the following issue **without using Python**, and explain your reasoning.
#
# a. ```hello = "hello"```
# b. ```_var = 100```
# c. ```!var_1 = 200```
# d. ```print = "print me"```
# e. ```False = 0```

# %% [markdown]
# Write your answer here
#
# a. Looks good
#
# b. Looks good
#
# c. It will not work because you cannot use "!" to declare the variable
#
# d. print is a reserved word, you cannot use it to declare a variable
#
# e. Same is here, False is a reserved word for boolean type of data

# %% [markdown]
# ## Challenges
#
# Please describe the challenges you faced during the exercise.

# %% [markdown]
# Write your challenges here
