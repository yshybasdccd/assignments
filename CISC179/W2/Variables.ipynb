# %% [markdown]
# <a href="https://colab.research.google.com/github/yshybasdccd/assignments/blob/main/CISC179/W2/Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python variables
#
# Variables are human-friendly names of memory locations
#
# ## Objective
# 1. Understand how to define variables in Python.
# 2. Gain a clear understanding of how the Python interpreter allocates memory addresses to variables.
# 3. Skilled in troubleshooting techniques.
#
# ## Prerequisite
#
# - Python literals lecture & lab
# - Programming variables lecture
#
# ## What do you need to complete this exercise?
#
# You can perform this exercise in any Python IDE, including JupyterLab or Google Colab.

# %% [markdown]
# ### Variable definition
#
# No need to declare the variable data type; variables can be assigned values or strings as needed.

# %%
var1 = 10 # integer
print(type(var1)) # var1 holds integer data type
var2 = 100.0 # float
print(type(var2))  # var2 holds float data type
print(var1 * var2)  # var1 * var2 - float data type
str1 = "Hello World"
type(str1)
print(str1)
str2 = 'Single quote can also be used'
type(str2)
print(str2)
var1 = "Now I am a string data type"
del(var1) # delete the var1
# Out:
# <class 'int'>
# <class 'float'>
# 1000.0
# Hello World
# Single quote can also be used

# %% [markdown]
# ### Variable memory usage

# %%
var1 = 10

# %%
# Check the memory address of var1 by using the following statement
print(hex(id(var1)))
# Out:
# 0xa40ca8

# %%
var1 = 100
# Check the memory address of var1 again

# %%
# Write your code here
print(hex(id(var1)))
# Out:
# 0xa417e8

# %% [markdown]
# You should see two distinct addresses for var1. Explain why there are two different addresses and what happened to the first one.

# %%
var2 = 100
# Write your print statement
# Check the memory address of var2. Did the Python interpreter assign a new memory address or reuse the existing one?

# %%
# Write your code here
print(hex(id(var2)))
#no, the address is the same. Python interpreter reused the existing address.
# Out:
# 0xa417e8

# %% [markdown]
# ### Memory map

# %%
str1 = "Hello"
str2 = "World"

# %%
# Find out the memory addresses of each character in str1 and str2.
# The following is the example

# %%
# Use the same method as described above to find the addresses of additional characters and complete the table below.
for i in str1:
  print(hex(id(i)), i)
for i2 in str2:
  print(hex(id(i2)), i2)
# Out:
# 0xa4b9e8 H
# 0xa4c040 e
# 0xa4c1c8 l
# 0xa4c1c8 l
# 0xa4c270 o
# 0xa4bd30 W
# 0xa4c270 o
# 0xa4c318 r
# 0xa4c1c8 l
# 0xa4c008 d

# %% [markdown]
# | Address in hexadecimal | Char |
# | ---------------------- | ---- |
# | # 0xa4b9e8                     |   H   |
# | #  0xa4c040                    |   e   |
# | # 0xa4c1c8                     |   l   |
# | #    0xa4c1c8                  |   l   |
# | #   0xa4c270                   |   o   |
# | #    0xa4bd30                  |   W   |
# | #   0xa4c270                   |   o   |
# | #    0xa4c318                  |   r   |
# | #    0xa4c1c8                  |   l   |
# | #   0xa4c008                   |   d   |

# %% [markdown]
# ### Problem-solving
#
#  Let the variable ```x``` be ```dog``` and the variable ```y``` be ```cat```. Write the values returned by the following operations: **Try solving without writing in Python.**
# -  x + y
# -  "the " + x + " chases the " + y
# -  x * 4

# %% [markdown]
# Write your answer here
# 1. dogcat
# 2. the dog chases the cat
# 3. dogdogdogdog

# %% [markdown]
# If ```x = 50```. Use an assignment statement to increment the value of ```x``` by 1.

# %%
# Write your code here
x=50
x=x+1 # or x=+1
print(x)
# Out:
# 51

# %% [markdown]
# ### Troubleshooting
#
# Please troubleshoot the following issue **without using Python**, and explain your reasoning.
#
# a. ```hello = "hello"```
# b. ```_var = 100```
# c. ```!var_1 = 200```
# d. ```print = "print me"```
# e. ```False = 0```

# %% [markdown]
# Write your answer here
# a. Looks good
# b. Looks good
# c. It will not work because you cannot use "!" to declare the variable
# d. print is a reserved word, you cannot use it to declare a variable
# e. Same is here, False is a reserved word for boolean type of data

# %% [markdown]
# ## Challenges
#
# Please describe the challenges you faced during the exercise.

# %% [markdown]
# There were no challenges in this exercise. It was very interesting to learn about the memory allocation in python
